# %%
import os
from pathlib import Path

repo_root = Path.cwd()
mlserver_dir = repo_root / "MlServer"
if repo_root.name != "MlServer":
    if mlserver_dir.exists():
        os.chdir(mlserver_dir)
    else:
        raise FileNotFoundError("MlServer directory not found relative to current working directory.")

print(f"cwd set to: {Path.cwd()}")
# Out:
# cwd set to: c:\Users\eriol\Projects\AtsScorer\MlServer

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pymupdf
from transformers import AutoModelForCausalLM, AutoTokenizer

# %%
data_dir = Path("data")
resume_files = sorted((data_dir / "resumes").glob("*.pdf"))

# %%
def extract_lines(path:  str | Path) -> list[dict]:
    """
    Extract visual lines from a PDF with basic formatting info.
    Merges bullet points with their following text. 
    
    Returns: 
        list of dicts with: text, is_bold, font_size, page
    """
    if isinstance(path, Path):
        path = path.resolve()
    
    lines = []
    prev_top = None
    prev_is_bullet = False
    prev_page = None
    
    with pymupdf.open(path) as doc:        
        for page_num, page in enumerate(doc):  # type: ignore
            blocks = page.get_text("dict")["blocks"]
            
            for block in blocks:
                if block["type"] != 0:  # Skip images
                    continue
                
                for line in block["lines"]:
                    text = "".join(span["text"] for span in line["spans"]).strip()
                    
                    if not text:
                        continue
                    
                    first_span = line["spans"][0]
                    is_bold = bool(first_span["flags"] & 16)
                    font_size = round(first_span["size"], 1)
                    top = line["bbox"][1]
                    
                    # Bullet if short and non-ASCII
                    is_bullet_only = len(text) <= 2 and not text.isascii()
                    
                    # Try to merge with previous line if previous was a bullet
                    if lines and prev_page == page_num and prev_is_bullet:
                        vertical_gap = abs(top - prev_top)
                        
                        if vertical_gap < 5:
                            lines[-1]["text"] = lines[-1]["text"] + " " + text
                            prev_is_bullet = False
                            prev_top = top
                            continue
                    
                    lines.append({
                        "text":  text,
                        "is_bold": is_bold,
                        "font_size": font_size,
                        "page":  page_num
                    })
                    
                    # keep track of the line above the current line
                    prev_top = top
                    prev_is_bullet = is_bullet_only
                    prev_page = page_num
    
    return sorted(lines, key=lambda x: x["page"])

# %%
def find_education_section(lines: list[dict]) -> dict | None:
    """
    Find section header profile by locating 'Education' section.
    """
    for line in lines:
        if "education" in line["text"].lower() and len(line["text"]) <= 30:
            return {
                "font_size": line["font_size"],
                "is_bold": line["is_bold"],
                "is_all_caps": line["text"].isupper()
            }
    return None

# %%
def matches_education_format(line: dict, profile: dict) -> bool:
    """Check if line matches section header profile."""
    if len(line["text"]) > 50:
        return False
    if line["font_size"] != profile["font_size"]:
        return False
    if line["is_bold"] != profile["is_bold"]:
        return False
    if line["text"].isupper() != profile["is_all_caps"]:
        return False
    return True

# %%
def extract_sections(file_path: str | Path) -> dict[str, list[str]]:
    """
    Extract sections from a resume PDF.

    Returns:
        dict: section header -> list of content lines
    """
    lines = extract_lines(file_path)
    profile = find_education_section(lines)
    
    if not profile:
        print("WARNING: Could not find Education section!")
        return {}
    
    sections = {}
    current_header = None
    current_content = []
    for line in lines:
        if matches_education_format(line, profile):
            if current_header:
                sections[current_header] = current_content
            current_header = line["text"]
            current_content = []
        elif current_header:
            current_content.append(line["text"])
    
    # Save last section
    if current_header:
        sections[current_header] = current_content
    
    return sections
